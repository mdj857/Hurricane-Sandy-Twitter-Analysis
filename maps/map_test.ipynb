# %%
import numpy as np
import pandas as pd
import plotly.plotly as py
import plotly
plotly.tools.set_credentials_file(username='javiertzepeda', api_key='pKSEE9IN1UNSL9E62spa')

tweets = pd.read_csv("../../ny_train_short.csv")
colors = ["rgb(0,116,217)","rgb(255,65,54)","rgb(133,20,75)","rgb(255,133,27)","lightgrey"]

scale = 1000;

#for tweets in chunks:
    
tweets.dropna(subset=["lat_final", "lng_final"], inplace=True)
#tweets.to_csv("../../short.csv", header=False, index=False, mode="a")

tweetmap = []

####
tweets_affected = tweets[tweets["damage"] == "affected"]
tweets_unknown = tweets[tweets["damage"] == "unknown"]
tweets_minor = tweets[tweets["damage"] == "minor"]
tweets_major = tweets[tweets["damage"] == "major"]
tweets_destroyed = tweets[tweets["damage"] == "destroyed"]
####


unknown_points = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lon = tweets_unknown['lng_final'],
    lat = tweets_unknown['lat_final'],
    text = tweets_unknown['text'],
    marker = dict(
        size = tweets_unknown['user_followers_count']/scale,
        color = "rgb(178, 174, 174)",
        line = dict(width=0.5, color='rgb(178, 174, 174)'),
        sizemode = 'area'
    ),
    #name = tweets_unknown['user_id'])
    name = "Unknown")
tweetmap.append(unknown_points)

affected_points = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lon = tweets_affected['lng_final'],
    lat = tweets_affected['lat_final'],
    text = tweets_affected['text'],
    marker = dict(
        size = tweets_affected['user_followers_count']/scale,
        color = "rgb(244, 66, 244)",
        line = dict(width=0.5, color='rgb(244, 66, 244)'),
        sizemode = 'area'
    ),
    #name = tweets_affected['user_id'])
    name = "Affected")
tweetmap.append(affected_points)

minor_points = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lon = tweets_minor['lng_final'],
    lat = tweets_minor['lat_final'],
    text = tweets_minor['text'],
    marker = dict(
        size = tweets_minor['user_followers_count']/scale,
        color = "rgb(255, 255, 0)",
        line = dict(width=0.5, color='rgb(255, 255, 0)'),
        sizemode = 'area'
    ),
    #name = tweets_minor['user_id'])
    name = "Minor")
tweetmap.append(minor_points)

major_points = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lon = tweets_major['lng_final'],
    lat = tweets_major['lat_final'],
    text = tweets_major['text'],
    marker = dict(
        size = tweets_major['user_followers_count']/scale,
        color = "rgb(255, 178, 0)",
        line = dict(width=0.5, color='rgb(255, 178, 0)'),
        sizemode = 'area'
    ),
    #name = tweets_major['user_id'])
    name = "Major")
tweetmap.append(major_points)

destroyed_points = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lon = tweets_destroyed['lng_final'],
    lat = tweets_destroyed['lat_final'],
    text = tweets_destroyed['text'],
    marker = dict(
        size = tweets_destroyed['user_followers_count']/scale,
        color = "rgb(255, 0, 0)",
        line = dict(width=0.5, color='rgb(255, 0, 0)'),
        sizemode = 'area'
    ),
    #name = tweets_destroyed['user_id'])
    name = "Destroyed")
tweetmap.append(destroyed_points)


    #print tweets['lng_final'].iloc[i],tweets['lat_final'].iloc[i],tweets['text'].iloc[i]
layout = dict(
    title = 'Sandy Hurricane Tweets',
    showlegend = True,
    geo = dict(
        scope='usa',
        projection=dict( type='albers usa' ),
        showland = True,
        landcolor = 'rgb(217, 217, 217)',
        subunitwidth=1,
        countrywidth=1,
        subunitcolor="rgb(255, 255, 255)",
        countrycolor="rgb(255, 255, 255)"
    ),
)

fig = dict( data=tweetmap, layout=layout )
py.iplot( fig, validate=False, filename='d3-bubble-map-populations' )
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~javiertzepeda/0 or inside your plot.ly account where it is named 'd3-bubble-map-populations'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~javiertzepeda/0.embed" height="525px" width="100%"></iframe>
